# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\DELL\Downloads\data_clean.csv")
df
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
df.head()
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0           1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1           2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2           3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3           4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4           5    NaN      NaN  14.3     56     5    5  2010    56       S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar.R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      158 non-null    object
#  5   Month       158 non-null    object
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 12.5+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0       Ozone     Solar.R        Wind         Day    Year  \
# count  158.000000  120.000000  151.000000  158.000000  158.000000   158.0
# mean    79.500000   41.583333  185.403974    9.957595   16.006329  2010.0
# std     45.754781   32.620709   88.723103    3.511261    8.997166     0.0
# min      1.000000    1.000000    7.000000    1.700000    1.000000  2010.0
# 25%     40.250000   18.000000  119.000000    7.400000    8.000000  2010.0
# 50%     79.500000   30.500000  197.000000    9.700000   16.000000  2010.0
# 75%    118.750000   61.500000  257.000000   11.875000   24.000000  2010.0
# max    158.000000  168.000000  334.000000   20.700000   31.000000  2010.0
#
#              Temp
# count  158.000000
# mean    77.727848
# std      9.377877
# min     56.000000
# 25%     72.000000
# 50%     78.500000
# 75%     84.000000
# max     97.000000

# %%
df.rename(columns={"Solar.R":"Solar","Temp":"Temperature"},inplace=True)

# %%
df
# Out:
#      Unnamed: 0  Ozone  Solar  Wind Temp C Month  Day  Year  Temperature  \
# 0             1   41.0  190.0   7.4     67     5    1  2010           67
# 1             2   36.0  118.0   8.0     72     5    2  2010           72
# 2             3   12.0  149.0  12.6     74     5    3  2010           74
# 3             4   18.0  313.0  11.5     62     5    4  2010           62
# 4             5    NaN    NaN  14.3     56     5    5  2010           56
# ..          ...    ...    ...   ...    ...   ...  ...   ...          ...
# 153         154   41.0  190.0   7.4     67     5    1  2010           67
# 154         155   30.0  193.0   6.9     70     9   26  2010           70
# 155         156    NaN  145.0  13.2     77     9   27  2010           77
# 156         157   14.0  191.0  14.3     75     9   28  2010           75
# 157         158   18.0  131.0   8.0     76     9   29  2010           76
#
#     Weather
# 0         S
# 1         C
# 2        PS
# 3         S
# 4         S
# ..      ...
# 153       C
# 154      PS
# 155       S
# 156       S
# 157       C
#
# [158 rows x 10 columns]

# %%
df.Month.value_counts()
# Out:
# Month
# 9      34
# 5      31
# 7      31
# 8      31
# 6      30
# May     1
# Name: count, dtype: int64

# %%
df.loc[df["Month"]=='May',"Month"]=5

# %%
df.Month.unique()
# Out:
# array(['5', 5, '6', '7', '8', '9'], dtype=object)

# %%
df['Temp C'].unique()
# Out:
# array(['67', '72', '74', '62', '56', '66', '65', '59', '61', '69', 'C',
#        '68', '58', '64', '57', '73', '81', '79', '76', '78', '84', '85',
#        '82', '87', '90', '93', '92', '80', '77', '75', '83', '88', '89',
#        '91', '86', '97', '94', '96', '71', '63', '70'], dtype=object)

# %%
df['Month']=pd.to_numeric(df['Month'],errors='coerce')

# %%
df['Temp C']=pd.to_numeric(df['Temp C'],errors='coerce')

# %%
df['Month'].unique()
# Out:
# array([5, 6, 7, 8, 9], dtype=int64)

# %%
df['Month'].value_counts()
# Out:
# Month
# 9    34
# 5    32
# 7    31
# 8    31
# 6    30
# Name: count, dtype: int64

# %%
df['Month'].astype(int)
# Out:
# 0      5
# 1      5
# 2      5
# 3      5
# 4      5
#       ..
# 153    5
# 154    9
# 155    9
# 156    9
# 157    9
# Name: Month, Length: 158, dtype: int32

# %%
df.dtypes
# Out:
# Unnamed: 0       int64
# Ozone          float64
# Solar          float64
# Wind           float64
# Temp C         float64
# Month            int64
# Day              int64
# Year             int64
# Temperature      int64
# Weather         object
# dtype: object

# %%
df.dtypes
# Out:
# Unnamed: 0       int64
# Ozone          float64
# Solar          float64
# Wind           float64
# Temp C         float64
# Month            int64
# Day              int64
# Year             int64
# Temperature      int64
# Weather         object
# dtype: object

# %%
df['Month'] = df['Month'].astype(int)

# %%
df.dtypes
# Out:
# Unnamed: 0       int64
# Ozone          float64
# Solar          float64
# Wind           float64
# Temp C         float64
# Month            int32
# Day              int64
# Year             int64
# Temperature      int64
# Weather         object
# dtype: object

# %% [markdown]
# # Duplicate

# %%
df
# Out:
#      Unnamed: 0  Ozone  Solar  Wind  Temp C  Month  Day  Year  Temperature  \
# 0             1   41.0  190.0   7.4    67.0      5    1  2010           67
# 1             2   36.0  118.0   8.0    72.0      5    2  2010           72
# 2             3   12.0  149.0  12.6    74.0      5    3  2010           74
# 3             4   18.0  313.0  11.5    62.0      5    4  2010           62
# 4             5    NaN    NaN  14.3    56.0      5    5  2010           56
# ..          ...    ...    ...   ...     ...    ...  ...   ...          ...
# 153         154   41.0  190.0   7.4    67.0      5    1  2010           67
# 154         155   30.0  193.0   6.9    70.0      9   26  2010           70
# 155         156    NaN  145.0  13.2    77.0      9   27  2010           77
# 156         157   14.0  191.0  14.3    75.0      9   28  2010           75
# 157         158   18.0  131.0   8.0    76.0      9   29  2010           76
#
#     Weather
# 0         S
# 1         C
# 2        PS
# 3         S
# 4         S
# ..      ...
# 153       C
# 154      PS
# 155       S
# 156       S
# 157       C
#
# [158 rows x 10 columns]

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 153    False
# 154    False
# 155    False
# 156    False
# 157    False
# Length: 158, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Ozone, Solar, Wind, Temp C, Month, Day, Year, Temperature, Weather]
# Index: []

# %%
df.drop(columns=['Year'],inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0  Ozone  Solar  Wind  Temp C  Month  Day  Temperature Weather
# 0           1   41.0  190.0   7.4    67.0      5    1           67       S
# 1           2   36.0  118.0   8.0    72.0      5    2           72       C
# 2           3   12.0  149.0  12.6    74.0      5    3           74      PS
# 3           4   18.0  313.0  11.5    62.0      5    4           62       S
# 4           5    NaN    NaN  14.3    56.0      5    5           56       S

# %%
df.drop(columns=['Ozone','Month'])
# Out:
#      Unnamed: 0  Solar  Wind  Temp C  Day  Temperature Weather
# 0             1  190.0   7.4    67.0    1           67       S
# 1             2  118.0   8.0    72.0    2           72       C
# 2             3  149.0  12.6    74.0    3           74      PS
# 3             4  313.0  11.5    62.0    4           62       S
# 4             5    NaN  14.3    56.0    5           56       S
# ..          ...    ...   ...     ...  ...          ...     ...
# 153         154  190.0   7.4    67.0    1           67       C
# 154         155  193.0   6.9    70.0   26           70      PS
# 155         156  145.0  13.2    77.0   27           77       S
# 156         157  191.0  14.3    75.0   28           75       S
# 157         158  131.0   8.0    76.0   29           76       C
#
# [158 rows x 7 columns]

# %%
df.drop(index=[1])
# Out:
#      Unnamed: 0  Ozone  Solar  Wind  Temp C  Month  Day  Temperature Weather
# 0             1   41.0  190.0   7.4    67.0      5    1           67       S
# 2             3   12.0  149.0  12.6    74.0      5    3           74      PS
# 3             4   18.0  313.0  11.5    62.0      5    4           62       S
# 4             5    NaN    NaN  14.3    56.0      5    5           56       S
# 5             6   28.0    NaN  14.9    66.0      5    6           66       C
# ..          ...    ...    ...   ...     ...    ...  ...          ...     ...
# 153         154   41.0  190.0   7.4    67.0      5    1           67       C
# 154         155   30.0  193.0   6.9    70.0      9   26           70      PS
# 155         156    NaN  145.0  13.2    77.0      9   27           77       S
# 156         157   14.0  191.0  14.3    75.0      9   28           75       S
# 157         158   18.0  131.0   8.0    76.0      9   29           76       C
#
# [157 rows x 9 columns]

# %%
df.drop(index=[1,3])
# Out:
#      Unnamed: 0  Ozone  Solar  Wind  Temp C  Month  Day  Temperature Weather
# 0             1   41.0  190.0   7.4    67.0      5    1           67       S
# 2             3   12.0  149.0  12.6    74.0      5    3           74      PS
# 4             5    NaN    NaN  14.3    56.0      5    5           56       S
# 5             6   28.0    NaN  14.9    66.0      5    6           66       C
# 6             7   23.0  299.0   8.6    65.0      5    7           65      PS
# ..          ...    ...    ...   ...     ...    ...  ...          ...     ...
# 153         154   41.0  190.0   7.4    67.0      5    1           67       C
# 154         155   30.0  193.0   6.9    70.0      9   26           70      PS
# 155         156    NaN  145.0  13.2    77.0      9   27           77       S
# 156         157   14.0  191.0  14.3    75.0      9   28           75       S
# 157         158   18.0  131.0   8.0    76.0      9   29           76       C
#
# [156 rows x 9 columns]

# %% [markdown]
# # Missing Value Imputation

# %% [raw]
# Reasons Of missing values
#
#     Data entry errors
#     Issue with machines
#     Improper data handling, etc.

# %% [markdown]
# # Tratment

# %% [raw]
# 0 to 5% missing values: drop rows
# 6 to 45%: replace the missing values
#  50%: drop column

# %%
df.head()
# Out:
#    Unnamed: 0  Ozone  Solar  Wind  Temp C  Month  Day  Temperature Weather
# 0           1   41.0  190.0   7.4    67.0      5    1           67       S
# 1           2   36.0  118.0   8.0    72.0      5    2           72       C
# 2           3   12.0  149.0  12.6    74.0      5    3           74      PS
# 3           4   18.0  313.0  11.5    62.0      5    4           62       S
# 4           5    NaN    NaN  14.3    56.0      5    5           56       S

# %%
df.isna()
# Out:
#      Unnamed: 0  Ozone  Solar   Wind  Temp C  Month    Day  Temperature  \
# 0         False  False  False  False   False  False  False        False
# 1         False  False  False  False   False  False  False        False
# 2         False  False  False  False   False  False  False        False
# 3         False  False  False  False   False  False  False        False
# 4         False   True   True  False   False  False  False        False
# ..          ...    ...    ...    ...     ...    ...    ...          ...
# 153       False  False  False  False   False  False  False        False
# 154       False  False  False  False   False  False  False        False
# 155       False   True  False  False   False  False  False        False
# 156       False  False  False  False   False  False  False        False
# 157       False  False  False  False   False  False  False        False
#
#      Weather
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ..       ...
# 153    False
# 154    False
# 155    False
# 156    False
# 157    False
#
# [158 rows x 9 columns]

# %%
df.isna().sum()
# Out:
# Unnamed: 0      0
# Ozone          38
# Solar           7
# Wind            0
# Temp C          1
# Month           0
# Day             0
# Temperature     0
# Weather         3
# dtype: int64

# %%
import seaborn as sns
sns.heatmap(df.isna())
# Out:
# <Axes: >

# %%
df.isna().sum()
# Out:
# Unnamed: 0      0
# Ozone          38
# Solar           7
# Wind            0
# Temp C          1
# Month           0
# Day             0
# Temperature     0
# Weather         3
# dtype: int64

# %%
len(df)
# Out:
# 158

# %% [raw]
# # % of missing values
# for i in df.isna().sum():
#   print((i/len(df))*100)
# # Ozone: replace missing values as missing values are in the range of 6 to 45%
# # Solar, Weather: drop missing values
# # but we will treat missing values
# # Ozone and Solar are numeric columns. If outliers are present in that column, replace missing values with median,
# # if no outliers in column replace missing value with mean
# # if categorical column replace missing value with mode.
#
# # 0 to 5 % missing values: drop rows
# # 6 to 45 %: replace the missing values
# # 50%: drop column

# %%
# % of missing values
for i in df.isna().sum():
  print((i/len(df))*100)
# Ozone: replace missing values as missing values are in the range of 6 to 45%
# Solar, Weather: drop missing values
# but we will treat missing values
# Ozone and Solar are numeric columns. If outliers are present in that column, replace missing values with median,
# if no outliers in column replace missing value with mean
# if categorical column replace missing value with mode.

# 0 to 5 % missing values: drop rows
# 6 to 45 %: replace the missing values
# 50%: drop column
# Out:
# 0.0
# 24.050632911392405
# 4.430379746835443
# 0.0
# 0.6329113924050633
# 0.0
# 0.0
# 0.0
# 1.89873417721519

# %%
import matplotlib.pyplot as plt
df.hist()
plt.tight_layout()

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
sns.boxplot(x= df['Wind'])
# Out:
# <Axes: xlabel='Wind'>

# %%
ozone_median = df['Ozone'].median()

# %%
ozone_median
# Out:
# 30.5

# %%
df['Ozone'].fillna(ozone_median,inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_1992\1769586071.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Ozone'].fillna(ozone_median,inplace=True)

# %%
df.isna().sum()
# Out:
# Unnamed: 0     0
# Ozone          0
# Solar          7
# Wind           0
# Temp C         1
# Month          0
# Day            0
# Temperature    0
# Weather        3
# dtype: int64

# %%
df['Solar'].mean()
# Out:
# 185.40397350993376

# %%
df['Solar'].fillna(df['Solar'].mean(),inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_1992\4190145745.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Solar'].fillna(df['Solar'].mean(),inplace=True)

# %%
df.isna().sum()
# Out:
# Unnamed: 0     0
# Ozone          0
# Solar          0
# Wind           0
# Temp C         1
# Month          0
# Day            0
# Temperature    0
# Weather        3
# dtype: int64

# %%
df.value_counts()
# Out:
# Unnamed: 0  Ozone  Solar  Wind  Temp C  Month  Day  Temperature  Weather
# 1           41.0   190.0  7.4   67.0    5      1    67           S          1
# 110         23.0   115.0  7.4   76.0    8      18   76           C          1
# 103         30.5   137.0  11.5  86.0    8      11   86           S          1
# 104         44.0   192.0  11.5  86.0    8      12   86           S          1
# 105         28.0   273.0  11.5  82.0    8      13   82           S          1
#                                                                            ..
# 54          30.5   91.0   4.6   76.0    6      23   76           PS         1
# 55          30.5   250.0  6.3   76.0    6      24   76           S          1
# 56          30.5   135.0  8.0   75.0    6      25   75           C          1
# 57          30.5   127.0  8.0   78.0    6      26   78           PS         1
# 158         18.0   131.0  8.0   76.0    9      29   76           C          1
# Name: count, Length: 154, dtype: int64

# %%
df.mode()
# Out:
#      Unnamed: 0  Ozone       Solar  Wind  Temp C  Month   Day  Temperature  \
# 0             1   30.5  185.403974  11.5    81.0    9.0   1.0         81.0
# 1             2    NaN         NaN   NaN     NaN    NaN  26.0          NaN
# 2             3    NaN         NaN   NaN     NaN    NaN  27.0          NaN
# 3             4    NaN         NaN   NaN     NaN    NaN  28.0          NaN
# 4             5    NaN         NaN   NaN     NaN    NaN  29.0          NaN
# ..          ...    ...         ...   ...     ...    ...   ...          ...
# 153         154    NaN         NaN   NaN     NaN    NaN   NaN          NaN
# 154         155    NaN         NaN   NaN     NaN    NaN   NaN          NaN
# 155         156    NaN         NaN   NaN     NaN    NaN   NaN          NaN
# 156         157    NaN         NaN   NaN     NaN    NaN   NaN          NaN
# 157         158    NaN         NaN   NaN     NaN    NaN   NaN          NaN
#
#     Weather
# 0         S
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ..      ...
# 153     NaN
# 154     NaN
# 155     NaN
# 156     NaN
# 157     NaN
#
# [158 rows x 9 columns]

# %% [markdown]
# Outlier Detection

# %% [raw]
# Histogram
# Boxplot
# Dascriptive Statistics

# %%
df.describe()
# Out:
#        Unnamed: 0       Ozone       Solar        Wind      Temp C       Month  \
# count  158.000000  158.000000  158.000000  158.000000  157.000000  158.000000
# mean    79.500000   38.917722  185.403974    9.957595   77.751592    7.031646
# std     45.754781   28.794730   86.722647    3.511261    9.403120    1.438421
# min      1.000000    1.000000    7.000000    1.700000   56.000000    5.000000
# 25%     40.250000   21.000000  127.000000    7.400000   72.000000    6.000000
# 50%     79.500000   30.500000  192.500000    9.700000   79.000000    7.000000
# 75%    118.750000   45.000000  255.000000   11.875000   84.000000    8.000000
# max    158.000000  168.000000  334.000000   20.700000   97.000000    9.000000
#
#               Day  Temperature
# count  158.000000   158.000000
# mean    16.006329    77.727848
# std      8.997166     9.377877
# min      1.000000    56.000000
# 25%      8.000000    72.000000
# 50%     16.000000    78.500000
# 75%     24.000000    84.000000
# max     31.000000    97.000000

# %%
df.hist()
plt.tight_layout()

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
sns.boxplot(x = df['Ozone'])
# Out:
# <Axes: xlabel='Ozone'>

# %%
def UserFunction():
    print("Hello")
    print("Function Introduction")

# %%
UserFunction()
# Out:
# Hello
# Function Introduction

# %%
def outlier_detection(data,colname):
    q1 = data[colname].quantile(0.25)
    q3 = data[colname].quantile(0.75)
    iqr = q3-q1

upper_extreme = q3 + (1.5 * iqr)
lower_extreme = q1 - (1.5 * iqr)

return lower_extreme, upper_extreme,q1,q3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 6
#       3     q3 = data[colname].quantile(0.75)
#       4     iqr = q3-q1
# ----> 6 upper_extreme = q3 + (1.5 * iqr)
#       7 lower_extreme = q1 - (1.5 * iqr)
#       9 return lower_extreme, upper_extreme,q1,q3
#
# NameError: name 'q3' is not defined

# %%
outlier_detection(df,'Ozone')

# %%
import plotly.express as pe

# %%
df[df['Ozone']>81.0]

# %%
df.loc[df['Ozone']>81.0,'Ozone'] = 81.0

# %%
df.loc
